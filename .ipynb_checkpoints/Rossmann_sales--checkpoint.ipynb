# %%
                         Rossmann Sales Prediction     
Rossmann operates over 3,000 drug stores in 7 European countries. Currently, Rossmann store managers are tasked with predicting their daily sales for up to six weeks in advance. Store sales are influenced by many factors, including promotions, competition, school and state holidays, seasonality, and locality. With thousands of individual managers predicting sales based on their unique circumstances, the accuracy of results can be quite varied.
In their first Kaggle competition, Rossmann is challenging you to predict 6 weeks of daily sales for 1,115 stores located across Germany. Reliable sales forecasts enable store managers to create effective staff schedules that increase productivity and motivation. By helping Rossmann create a robust prediction model, you will help store managers stay focused on what’s most important to them: their customers and their teams!

# %% [markdown]
# Loading the files
# train.csv - historical data including Sales
# test.csv - historical data excluding Sales
#
# At a glance of the data, we could see missing values.So data needs missing value treatment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from statsmodels.tsa.arima_model import ARIMA

train_data = pd.read_csv("D:/Data Science/Projects/Kaggle/Rossmann/train/train.csv", parse_dates = True, low_memory = False,index_col = 'Date')
test_data  = pd.read_csv("D:/Data Science/Projects/Kaggle/Rossmann/test/test.csv", parse_dates = True, low_memory = False,index_col ='Date') 
store_data = pd.read_csv("D:/Data Science/Projects/Kaggle/Rossmann/store/store.csv", parse_dates = True, low_memory = False)

train_data.index
# Out:
# DatetimeIndex(['2015-07-31', '2015-07-31', '2015-07-31', '2015-07-31',
#                '2015-07-31', '2015-07-31', '2015-07-31', '2015-07-31',
#                '2015-07-31', '2015-07-31',
#                ...
#                '2013-01-01', '2013-01-01', '2013-01-01', '2013-01-01',
#                '2013-01-01', '2013-01-01', '2013-01-01', '2013-01-01',
#                '2013-01-01', '2013-01-01'],
#               dtype='datetime64[ns]', name='Date', length=1017209, freq=None)

# %% [markdown]
# Data fields
#
# Most of the fields are self-explanatory. The following are descriptions for those that aren't.
#
# Id               - an Id that represents a (Store, Date) duple within the test set
# Store            - a unique Id for each store
# Sales            - the turnover for any given day (this is what you are predicting)
# Customers        - the number of customers on a given day
# Open             - an indicator for whether the store was open: 0 = closed, 1 = open
# StateHoliday     - indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays. Note that                    all schools are closed on public holidays and weekends. a = public holiday, b = Easter holiday, c =
#                    Christmas, 0 = None
# SchoolHoliday    - indicates if the (Store, Date) was affected by the closure of public schools
# StoreType        - differentiates between 4 different store models: a, b, c, d
# Assortment       - describes an assortment level: a = basic, b = extra, c = extended
# CompetitionDistance - distance in meters to the nearest competitor store
# CompetitionOpenSince[Month/Year] - gives the approximate year and month of the time the nearest competitor was opened
# Promo            - indicates whether a store is running a promo on that day
# Promo2           - Promo2 is a continuing and consecutive promotion for some stores: 0 = store is not participating, 1 = store                      is participating
# Promo2Since[Year/Week] - describes the year and calendar week when the store started participating in Promo2
# PromoInterval    - describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew. E.g.                    "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store

# %%
print("Train_data total: ", train_data.shape)
train_data.head()

# %%
print("Test_data total: ", test_data.shape)
test_data.head()
# Out:
# Test_data total:  (41088, 7)
#             Id  Store  DayOfWeek  Open  Promo StateHoliday  SchoolHoliday
# Date
# 2015-09-17   1      1          4   1.0      1            0              0
# 2015-09-17   2      3          4   1.0      1            0              0
# 2015-09-17   3      7          4   1.0      1            0              0
# 2015-09-17   4      8          4   1.0      1            0              0
# 2015-09-17   5      9          4   1.0      1            0              0

# %%
print("Store_data total: ", store_data.shape)
store_data.head()
# Out:
# Store_data total:  (1115, 10)
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# ...

# %% [markdown]
# Statitics of each file

# %%
train_data.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# ...

# %%
test_data.describe()
# Out:
#                  Id         Store     DayOfWeek          Open         Promo  \
# count  41088.000000  41088.000000  41088.000000  41077.000000  41088.000000
# mean   20544.500000    555.899533      3.979167      0.854322      0.395833
# std    11861.228267    320.274496      2.015481      0.352787      0.489035
# min        1.000000      1.000000      1.000000      0.000000      0.000000
# 25%    10272.750000    279.750000      2.000000      1.000000      0.000000
# 50%    20544.500000    553.500000      4.000000      1.000000      0.000000
# 75%    30816.250000    832.250000      6.000000      1.000000      1.000000
# max    41088.000000   1115.000000      7.000000      1.000000      1.000000
#
#        SchoolHoliday
# count   41088.000000
# mean        0.443487
# std         0.496802
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %%
store_data.describe()
# Out:
#             Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.00000          1112.000000                 761.000000
# mean    558.00000          5404.901079                   7.224704
# std     322.01708          7663.174720                   3.212348
# min       1.00000            20.000000                   1.000000
# 25%     279.50000           717.500000                   4.000000
# 50%     558.00000          2325.000000                   8.000000
# 75%     836.50000          6882.500000                  10.000000
# max    1115.00000         75860.000000                  12.000000
#
#        CompetitionOpenSinceYear       Promo2  Promo2SinceWeek  Promo2SinceYear
# count                761.000000  1115.000000       571.000000       571.000000
# mean                2008.668857     0.512108        23.595447      2011.763573
# std                    6.195983     0.500078        14.141984         1.674935
# ...

# %% [markdown]
# EDA and handling missing values

# %% [markdown]
# Missing Values
# 1.Closed stores and zero sales stores
# 2.opened stores with zero sales
# 3.

# %%
clssales = train_data[(train_data.Open == 0) & (train_data.Sales == 0)]
print("clssales total: ", clssales.shape)
clssales.head()
# Out:
# clssales total:  (172817, 8)
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31    292          5      0          0     0      1            0
# 2015-07-31    876          5      0          0     0      1            0
# 2015-07-30    292          4      0          0     0      1            0
# 2015-07-30    876          4      0          0     0      1            0
# 2015-07-29    292          3      0          0     0      1            0
#
#             SchoolHoliday
# Date
# 2015-07-31              1
# 2015-07-31              1
# 2015-07-30              1
# 2015-07-30              1
# 2015-07-29              1

# %%
nosales = train_data[(train_data.Open!=0) &(train_data.Sales == 0)]
print("nosales total: ", nosales.shape)
nosales.head()
# Out:
# nosales total:  (54, 8)
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-05-15    971          5      0          0     1      0            0
# 2015-03-26    674          4      0          0     1      0            0
# 2015-02-05    699          4      0          0     1      1            0
# 2014-10-01    708          3      0          0     1      1            0
# 2014-09-22    357          1      0          0     1      0            0
#
#             SchoolHoliday
# Date
# 2015-05-15              1
# 2015-03-26              0
# 2015-02-05              0
# 2014-10-01              0
# 2014-09-22              0

# %%
print("Closed stores and no sales")
clsnosales = train_data[(train_data["Open"] != 0) & (train_data['Sales'] != 0)]

print("In total: ", clsnosales.shape)
# Out:
# Closed stores and no sales
# In total:  (844338, 8)

# %%
store_data.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
store_data[pd.isnull(store_data.CompetitionDistance)]
# Out:
#      Store StoreType Assortment  CompetitionDistance  \
# 290    291         d          a                  NaN
# 621    622         a          c                  NaN
# 878    879         d          a                  NaN
#
#      CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 290                        NaN                       NaN       0
# 621                        NaN                       NaN       0
# 878                        NaN                       NaN       1
#
#      Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 290              NaN              NaN              NaN
# 621              NaN              NaN              NaN
# 878              5.0           2013.0  Feb,May,Aug,Nov

# %%
store_data['CompetitionDistance'].fillna(store_data['CompetitionDistance'].median(), inplace = True)

# %%
store_data.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %% [markdown]
# Merging train_data and store_data

# %%
train_store = pd.merge(train_data, store_data, how = 'inner', on = 'Store')

print("In total: ", train_store.shape)
train_store.head()
# Out:
# In total:  (1017209, 17)
#    Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5   5263        555     1      1            0
# 1      1          4   5020        546     1      1            0
# 2      1          3   4782        523     1      1            0
# 3      1          2   5011        560     1      1            0
# 4      1          1   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         c          a               1270.0
# 2              1         c          a               1270.0
# 3              1         c          a               1270.0
# 4              1         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                        9.0                    2008.0       0
# ...

# %% [markdown]
# To see the sales by store type and the customers visited

# %%
train_store.groupby('StoreType')['Customers', 'Sales'].sum()
# Out:
#            Customers       Sales
# StoreType
# a          363541434  3165334859
# b           31465621   159231395
# c           92129705   783221426
# d          156904995  1765392943

# %% [markdown]
# Here type a is in first place and next is type d in sales

# %% [markdown]
# Feature selection to understand the sales per customer per store, the mean value is round 9.50 per day.

# %%
train_data['SalePerCustomer'] = train_data['Sales']/train_data['Customers']
train_data['SalePerCustomer'].describe()
# Out:
# count    844340.000000
# mean          9.493619
# std           2.197494
# min           0.000000
# 25%           7.895563
# 50%           9.250000
# 75%          10.899729
# max          64.957854
# Name: SalePerCustomer, dtype: float64

# %% [markdown]
# Corelation Analysis : correlation matrix

# %%
c = '#11117F' # basic color for plots
corr_all = train_store.drop('Open', axis = 1).corr()

# Set up the matplotlib figure
f, ax = plt.subplots(figsize = (15, 8))

mask = np.zeros_like(corr_all, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True


# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_all, mask = mask,
            square = True, linewidths = .5, ax = ax, cmap = "CMRmap")      
plt.show()

# %%
sns.factorplot(data = train_store, x = 'DayOfWeek', y = "Sales", 
               col = 'Promo', 
               row = 'Promo2',
               hue = 'Promo2',
               palette = 'BuPu',
               color = c)

# %%
# data extraction
train_data['Year'] = train_data.index.year
train_data['Month'] = train_data.index.month
train_data['Day'] = train_data.index.day
train_data['WeekOfYear'] = train_data.index.weekofyear

# %%
train_data['Sales'] = train_data['Sales'] * 1.0

sales_a = train_data[train_data.Store == 2]['Sales']
sales_b = train_data[train_data.Store == 85]['Sales'].sort_index(ascending = True) # solve the reverse order
sales_c = train_data[train_data.Store == 1]['Sales']
sales_d = train_data[train_data.Store == 13]['Sales']

f, (ax1, ax2, ax3, ax4) = plt.subplots(4, figsize = (12, 13))

# store types
sales_a.resample('W').sum().plot(color = c, ax = ax1)
sales_b.resample('W').sum().plot(color = c, ax = ax2)
sales_c.resample('W').sum().plot(color = c, ax = ax3)
sales_d.resample('W').sum().plot(color = c, ax = ax4)

# %% [raw]
# Trends of sales by store types A, B, C, D

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, figsize = (12, 13))

# monthly
decomposition_a = seasonal_decompose(sales_a, model = 'additive', freq = 365)
decomposition_a.trend.plot(color = c, ax = ax1)

decomposition_b = seasonal_decompose(sales_b, model = 'additive', freq = 365)
decomposition_b.trend.plot(color = c, ax = ax2)

decomposition_c = seasonal_decompose(sales_c, model = 'additive', freq = 365)
decomposition_c.trend.plot(color = c, ax = ax3)

decomposition_d = seasonal_decompose(sales_d, model = 'additive', freq = 365)
decomposition_d.trend.plot(color = c, ax = ax4)

# %% [markdown]
# Autocorrelation

# %%
# figure for subplots
plt.figure(figsize = (15, 15))

# acf and pacf for sales Store A
plt.subplot(421); plot_acf(sales_a, lags = 50, ax = plt.gca(), color = c)
plt.subplot(422); plot_pacf(sales_a, lags = 50, ax = plt.gca(), color = c)

# acf and pacf for sales Store B
plt.subplot(423); plot_acf(sales_b, lags = 50, ax = plt.gca(), color = c)
plt.subplot(424); plot_pacf(sales_b, lags = 50, ax = plt.gca(), color = c)

# acf and pacf for sales Store C
plt.subplot(425); plot_acf(sales_c, lags = 50, ax = plt.gca(), color = c)
plt.subplot(426); plot_pacf(sales_c, lags = 50, ax = plt.gca(), color = c)

# acf and pacf for sales Store D
plt.subplot(427); plot_acf(sales_d, lags = 50, ax = plt.gca(), color = c)
plt.subplot(428); plot_pacf(sales_d, lags = 50, ax = plt.gca(), color = c)

plt.show()

# %% [markdown]
# Modeling

# %%
ts = pd.read_csv("D:/Data Science/Projects/Kaggle/Rossmann/train/train.csv", parse_dates = True, low_memory = False,)

# %%
ts = ts[(ts["Open"] != 0) & (ts['Sales'] != 0)]

# %%
sales = ts[ts.Store == 1].loc[:, ['Date', 'Sales']]

# %%
sales = sales.sort_index(ascending = False)

# %%
sales['Date'] = pd.DatetimeIndex(sales['Date'])
sales.dtypes
# Out:
# Date     datetime64[ns]
# Sales             int64
# dtype: object

# %%
sales = sales.rename(columns = {'Date': 'ds',
                                'Sales': 'y'})
sales.head()
# Out:
#                 ds     y
# 1014980 2013-01-02  5530
# 1013865 2013-01-03  4327
# 1012750 2013-01-04  4486
# 1011635 2013-01-05  4997
# 1009405 2013-01-07  7176

# %%
# create holidays dataframe
state_dates = ts[(ts.StateHoliday == 'a') | (ts.StateHoliday == 'b') & (ts.StateHoliday == 'c')].loc[:, 'Date'].values
school_dates = ts[ts.SchoolHoliday == 1].loc[:, 'Date'].values

state = pd.DataFrame({'holiday': 'state_holiday',
                      'ds': pd.to_datetime(state_dates)})
school = pd.DataFrame({'holiday': 'school_holiday',
                      'ds': pd.to_datetime(school_dates)})

holidays = pd.concat((state, school))      
holidays.head()
# Out:
#           ds        holiday
# 0 2015-06-04  state_holiday
# 1 2015-06-04  state_holiday
# 2 2015-06-04  state_holiday
# 3 2015-06-04  state_holiday
# 4 2015-06-04  state_holiday

# %%
transformed_data = train_data.drop(['Store', 'Customers'], axis=1)
transformed_data.head()
# Out:
#             DayOfWeek  Sales  Open  Promo StateHoliday  SchoolHoliday
# Date
# 2015-07-31          5   5263     1      1            0              1
# 2015-07-31          5   6064     1      1            0              1
# 2015-07-31          5   8314     1      1            0              1
# 2015-07-31          5  13995     1      1            0              1
# 2015-07-31          5   4822     1      1            0              1

# %%
from fbprophet import Prophet

# %%
my_model = Prophet(interval_width = 0.95, 
                   holidays = holidays)
my_model.fit(sales)

# dataframe that extends into future 6 weeks 
future_dates = my_model.make_future_dataframe(periods = 6*7)

print("First week to forecast.")
future_dates.tail(7)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\SONY\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# First week to forecast.
#             ds
# 816 2015-09-05
# 817 2015-09-06
# 818 2015-09-07
# 819 2015-09-08
# 820 2015-09-09
# 821 2015-09-10
# 822 2015-09-11

# %%
# predictions
forecast = my_model.predict(future_dates)

# preditions for last week
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)
# Out:
#             ds         yhat   yhat_lower   yhat_upper
# 816 2015-09-05  4107.928508  2493.467089  5684.084050
# 817 2015-09-06  4081.629384  2328.678722  5718.922796
# 818 2015-09-07  4177.429012  2696.390351  5706.994393
# 819 2015-09-08  3680.085778  2129.706077  5279.477922
# 820 2015-09-09  3566.493508  1993.457510  5097.373727
# 821 2015-09-10  3478.576447  1902.810853  5004.897791
# 822 2015-09-11  3733.596403  1986.542008  5313.437397

# %%
my_model.plot(forecast);

# %%
my_model.plot_components(forecast);
